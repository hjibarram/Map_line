# %%
import numpy as np
from MapLines.tools.line_fit import line_fit,line_fit_single
import MapLines.tools.tools as tol
import os.path as ptt

# %% [markdown]
# ## GET SDSS DATA

# %%
call='wget https://data.sdss.org/sas/dr16/eboss/spectro/redux/v5_13_0/spectra/lite/5715/spec-5715-56657-0166.fits .'
tol.sycall(call)
call='mv spec-5715-56657-0166.fits ../example_data/.'
tol.sycall(call)
# Out:
# --2025-04-07 12:51:16--  https://data.sdss.org/sas/dr16/eboss/spectro/redux/v5_13_0/spectra/lite/5715/spec-5715-56657-0166.fits
# Resolviendo data.sdss.org (data.sdss.org)... 155.101.19.133
# Conectando con data.sdss.org (data.sdss.org)[155.101.19.133]:443... conectado.
# 200 OKón HTTP enviada, esperando respuesta...
# Longitud: 218880 (214K) [application/octet-stream]
# Guardando como: ‘spec-5715-56657-0166.fits’
#
#      0K .......... .......... .......... .......... .......... 23%  909K 0s
#     50K .......... .......... .......... .......... .......... 46%  865K 0s
#    100K .......... .......... .......... .......... .......... 70% 15,3M 0s
#    150K .......... .......... .......... .......... .......... 93%  903K 0s
#    200K .......... ...                                        100% 45,8M=0,2s
#
# 2025-04-07 12:51:17 (1,22 MB/s) - ‘spec-5715-56657-0166.fits’ guardado [218880/218880]
#
# --2025-04-07 12:51:17--  http://./
# Resolviendo . (.)... falló: No existe ninguna dirección asociada al nombre.
# wget: no se pudo resolver la dirección del equipo ‘.’
# ACABADO --2025-04-07 12:51:17--
# Tiempo total de reloj: 0,6s
# Descargados: 1 ficheros, 214K en 0,2s (1,22 MB/s)

# %% [markdown]
# ## GET MANGA DATA

# %%
call='wget https://data.sdss.org/sas/dr17/manga/spectro/redux/v3_1_1/8144/stack/manga-8144-3702-LINCUBE.fits.gz .'
#tol.sycall(call) #/usr/local/bin/wget
call='mv manga-8144-3702-LINCUBE.fits.gz ../example_data/.'
#tol.sycall(call)

# %% [markdown]
# ## FIT SDSS Spectra

# %%
name_out='spec-5715-56657-0166'
cont=False
cont=True
error_c=True
lA1=4700.0
lA2=5050.0
skew=False
lorentz=False
outflow=False
flux_f=1/10.0   #Set the flux to 10^-16erg/s/A/cm2 instead of the SDSS 10^-17 erg/s/A/cm2   
dirt='../example_data/'
dir_out='outputs/'
ncpus=6
input_format='SDSS'
zt=0.0255
file1=dirt+'NAME.fits'.replace('NAME',name_out) 
if ptt.exists(dir_out) == False:
    tol.sycall('mkdir -p '+dir_out)
config_lines='line_prop_HbOIII.yml'
file_out=dir_out+'NAME_modelsV2'.replace('NAME',name_out)+'_HbOIII'
file_out2=dir_out+'NAME_paramV2'.replace('NAME',name_out)+'_HbOIII'
name_out2=name_out+'_HbOIII'
line_fit_single(file1,file_out,file_out2,name_out2,input_format=input_format,z=zt,lA1=lA1,lA2=lA2,ncpu=ncpus,lorentz=lorentz,
         skew=skew,flux_f=flux_f,erft=0.75,cont=cont,error_c=error_c,config_lines=config_lines,outflow=outflow)
# Out:
# /home/hjibarram/Packages/Python/py3.13/lib/python3.13/site-packages/MapLines/tools/line_fit.py:39: RuntimeWarning: divide by zero encountered in divide
#   pdl_dataE=1/np.sqrt(pdl_dataE)
# Multiprocessing took 7.7 seconds
# Best fit parameters:
# Ao0=7.799918540527275 dvo0=-16.680247370873047 fwhmo0=198.8000280229653 Ao2=7.799479969055123

# %%
name_out='spec-5715-56657-0166'
cont=False
cont=True
lab='_single'
single=True
error_c=True
broad=False    
br=''
lA1=6475.0
lA2=6650.0
lbh='_ha'
hbfit=True
skew=False
lorentz=False
skl=''  
flux_f=1.0      
dirt='../example_data/'
dir_out='outputs/'
ncpus=6
rvel=500
input_format='SDSS'
zt=0.0255
file1=dirt+'NAME.fits'.replace('NAME',name_out) 
if ptt.exists(dir_out) == False:
    tol.sycall('mkdir -p '+dir_out)
config_lines='line_prop_Ha.yml'
file_out=dir_out+'NAME_modelsV2'.replace('NAME',name_out)+lab+lbh+skl
file_out2=dir_out+'NAME_paramV2'.replace('NAME',name_out)+lab+lbh+skl
name_out2=name_out+lab+lbh+skl+br
line_fit_single(file1,file_out,file_out2,name_out2,input_format=input_format,z=zt,lA1=lA1,lA2=lA2,ncpu=ncpus,lorentz=lorentz,
         single=single,skew=skew,flux_f=flux_f,erft=0.75,dv1t=rvel,sim=True,cont=cont,hbfit=hbfit,error_c=error_c,broad=broad,
         config_lines=config_lines)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 30
#      28 file_out2=dir_out+'NAME_paramV2'.replace('NAME',name_out)+lab+lbh+skl
#      29 name_out2=name_out+lab+lbh+skl+br
# ---> 30 line_fit_single(file1,file_out,file_out2,name_out2,input_format=input_format,z=zt,lA1=lA1,lA2=lA2,ncpu=ncpus,lorentz=lorentz,
#      31          single=single,skew=skew,flux_f=flux_f,erft=0.75,dv1t=rvel,sim=True,cont=cont,hbfit=hbfit,error_c=error_c,broad=broad,
#      32          config_lines=config_lines)
#
# TypeError: line_fit_single() got an unexpected keyword argument 'single'

# %% [markdown]
# ## FIT MaNGA IFS Spectra

# %%
lA1hb=4700.0
lA2hb=5050.0
lA1ha=6350.0
lA2hab=6850.0
lA2ha=6650.0 

name_out='manga-8144-3702-LINCUBE'
test=True
sprogressd=True
cont=True
double=False
error_c=True
kskew=False
n_line=False   
dirt='../example_data/'
dir_out='outputs/'
ncpus=6
rvel=500
hbet=False
broad=True    
config_lines='line_prop.yml'
flux_f=1.0 
it=0
jt=0
zt=0.09785

if test:
    pgr_bar=False
    plot_f=True
else:
    plot_f=False
    if sprogressd:
        pgr_bar=False
    else:
        pgr_bar=True
if double:
    lab='_double'
    single=False
else:
    lab='_single'
    single=True
if broad:
    br=''
else:
    br='_broad'
if hbet:
    lA1=lA1hb
    lA2=lA2hb
    lbh='_hb'
    hbfit=True
else:
    lA1=lA1ha
    if broad:
        lA2=lA2hab
    else:
        lA2=lA2ha  
    lbh='_ha' 
    hbfit=False
if kskew:
    skew=True
    skl='_skew'
else:
    skew=False
    skl=''

file1=dirt+'NAME.fits.gz'.replace('NAME',name_out)
file2=dirt+'NAME.fits.gz'.replace('NAME',name_out)
file3=dirt+'NAMEM.fits.gz'.replace('NAMEM','Mask')  
if ptt.exists(dir_out) == False:
    tol.sycall('mkdir -p '+dir_out)
file_out=dir_out+'NAME_modelsV2'.replace('NAME',name_out)+lab+lbh+skl
file_out2=dir_out+'NAME_paramV2'.replace('NAME',name_out)+lab+lbh+skl
name_out2=name_out+lab+lbh+skl+br

line_fit(file1,file2,file3,file_out,file_out2,name_out2,z=zt,lA1=lA1,lA2=lA2,plot_f=plot_f,pgr_bar=pgr_bar,ncpu=ncpus,
         single=single,skew=skew,flux_f=flux_f,erft=0.75,dv1t=rvel,sim=True,cont=cont,hbfit=hbfit,test=test,error_c=error_c,
         broad=broad,i_t=it,j_t=jt,lorentz=lorentz,config_lines=config_lines,n_line=n_line)
